# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File ~\PycharmProjects\time_baselines\.venv\lib\site-packages\ipykernel\iostream.py:678, in OutStream.write(self, string)
#     676 is_child = not self._is_master_process()
#     677 # only touch the buffer in the IO thread to avoid races
# --> 678 with self._buffer_lock:
#     679     self._buffers[frozenset(parent.items())].write(string)
#     680 if is_child:
#     681     # mp.Pool cannot be trusted to flush promptly (or ever),
#     682     # and this helps.
#
# KeyboardInterrupt:

# %%
# print = 'PRINT'
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 print = 'PRINT'
# ----> 2 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
# %%timeit 
squares = [i**2 for i in range(10)]
# Out:
# 4.06 μs ± 285 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 4.42 μs ± 275 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# The mean and stdev of the runtime of the code.

# %% [markdown]
# ## Footnotes
