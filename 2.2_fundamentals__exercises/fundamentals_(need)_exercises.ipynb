# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# 1. Functions
# 2. Variables
# 3. Loops
# 4. If-else
# 5. *Indentations*
# 5. *Brackets*
# 6. *Packages*
# 7. *The dot (.)*

# %%
x, y = 3, 4
z = (x**2 + y**2)**0.5
print(x, y, z)
# Out:
# 3 4 5.0

# %% [markdown]
# | #  | Term         | Description                               |
# |----|--------------|-------------------------------------------|
# | 1  | Function     | Takes input and gives output              |
# | 2  | Arguments    | Input to a function                       |
# | 3  | Comments     | Words that are ignored by the interpreter |
# | 4  | Indentations | A tab space usually after for or if       |
# | 5  | Packages     | Add ons with additional functionalities   |
# | 6  | :            | Use to access attributes or methods       |
# | 7  | :            | For slicing                               |
# | 8  | []           | Create list                               |
# | 9  | [[ ], [ ]]   | Create 2d list                            |
# |10  | { }          | Create dictionary                         |

# %%
5/2 #division
5//2 #floor division
5%2 #modulo
